# %%
#Conectando ao google drive   
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importando Biblioteca Pandas
import pandas as pd

# %%
#Carregando arquivo (lendo)
#df = pd.read_csv('/content/drive/MyDrive/Bases de Dados/product.csv',error_bad_lines=False,delimiter =';')
df = pd.read_csv('/content/drive/MyDrive/Bases de Dados/product.csv',delimiter =';')

# %% [markdown]
# #Análise Exploratório dos Dados

# %%
#Ver as primeiras linhas do df
df.head()
# Out:
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name   price
# 0                  Bush Somerset Collection Bookcase  130.98
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  170.79
# 2  Self-Adhesive Address Labels for Typewriters b...    7.31
# 3      Bretford CR4500 Series Slim Rectangular Table  191.52
# 4                     Eldon Fold 'N Roll Cart System   13.98

# %%
#Ver as últimas linhas do df
df.tail()
# Out:
#            product_id         category sub_category  \
# 1888  TEC-AC-10002380       Technology  Accessories
# 1889  TEC-PH-10002817       Technology       Phones
# 1890  TEC-MA-10003589       Technology     Machines
# 1891  OFF-AP-10003099  Office Supplies   Appliances
# 1892  TEC-PH-10002645       Technology       Phones
#
#                                       product_name    price
# 1888  Sony 8GB Class 10 Micro SDHC R40 Memory Card    27.19
# 1889               RCA ViSYS 25425RE1 Corded phone   323.98
# 1890                  Cisco 8961 IP Phone Charcoal   224.94
# 1891                   Eureka Hand Vacuum, Bagless   197.72
# 1892                                         LG G2  1499.97

# %%
#Trazer as informações sobre a base
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1893 non-null   object
#  1   category      1893 non-null   object
#  2   sub_category  1893 non-null   object
#  3   product_name  1893 non-null   object
#  4   price         1893 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 74.1+ KB

# %%
#Trazer informações estatísticas sobre o meu df
df.describe()
#count	: contagem
#mean	: média
#std	: desvio padrão
#min	: mínimo
#25%	: 1° quartil
#50%	: 2° quartil ou mediana
#75%	: 3° quartil
#max	: máximo ou 4° quartil
# Out:
#               price
# count   1893.000000
# mean     141.428875
# std      664.230539
# min        0.440000
# 25%        8.740000
# 50%       25.420000
# 75%      101.340000
# max    22638.480000

# %%
#Trazer informações estatísticas da váriáceis quantitativas sobre o meu df
df.describe(include='O')
#count	: contagem
#unique : dados não repetidos
#top : valor que mais se repete
#freq : frequência que o valor aparece
# Out:
#              product_id         category sub_category product_name
# count              1893             1893         1893         1893
# unique             1861                3           17         1849
# top     FUR-FU-10004017  Office Supplies        Paper      Staples
# freq                  2             1097          284           10

# %% [markdown]
# #Renomeando colunas

# %%
#Visualizando nome das colunas
df.columns
# Out:
# Index(['product_id', 'category', 'sub_category', 'product_name', 'price'], dtype='object')

# %%
# 1° forma de renomear colunas
df.rename({'product_id':'Id_Product'},axis=1,inplace=True)

# %%
df.head()
# Out:
#         Id_Product         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name   price
# 0                  Bush Somerset Collection Bookcase  130.98
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  170.79
# 2  Self-Adhesive Address Labels for Typewriters b...    7.31
# 3      Bretford CR4500 Series Slim Rectangular Table  191.52
# 4                     Eldon Fold 'N Roll Cart System   13.98

# %%
# 2° forma de renomear colunas
df.rename(columns={'product_name':'Product'})
# Out:
#            Id_Product         category sub_category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 1888  TEC-AC-10002380       Technology  Accessories
# 1889  TEC-PH-10002817       Technology       Phones
# 1890  TEC-MA-10003589       Technology     Machines
# 1891  OFF-AP-10003099  Office Supplies   Appliances
# 1892  TEC-PH-10002645       Technology       Phones
#
#                                                 Product    price
# 0                     Bush Somerset Collection Bookcase   130.98
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...   170.79
# 2     Self-Adhesive Address Labels for Typewriters b...     7.31
# 3         Bretford CR4500 Series Slim Rectangular Table   191.52
# 4                        Eldon Fold 'N Roll Cart System    13.98
# ...                                                 ...      ...
# 1888       Sony 8GB Class 10 Micro SDHC R40 Memory Card    27.19
# 1889                    RCA ViSYS 25425RE1 Corded phone   323.98
# 1890                       Cisco 8961 IP Phone Charcoal   224.94
# 1891                        Eureka Hand Vacuum, Bagless   197.72
# 1892                                              LG G2  1499.97
#
# [1893 rows x 5 columns]

# %% [markdown]
# #Selecionando colunas específicas

# %%
#Selecionando apenas 1 colunas
df['price'].head()
# Out:
# 0    130.98
# 1    170.79
# 2      7.31
# 3    191.52
# 4     13.98
# Name: price, dtype: float64

# %%
#Criando um novo df a partir de uma coluna específica
df_1=df['price']
df_1.tail()
# Out:
# 1888      27.19
# 1889     323.98
# 1890     224.94
# 1891     197.72
# 1892    1499.97
# Name: price, dtype: float64

# %%
#Selecionando várias colunas
df[['category','price']].head()
# Out:
#           category   price
# 0        Furniture  130.98
# 1        Furniture  170.79
# 2  Office Supplies    7.31
# 3        Furniture  191.52
# 4  Office Supplies   13.98

# %% [markdown]
# #Funções matemáticas

# %%
#Soma
df['price'].sum()
# Out:
# 267724.86

# %%
#Média
df['price'].mean()
# Out:
# 141.42887480190174

# %%
#Mediana
df['price'].median()
# Out:
# 25.42

# %%
#Desvio padrão
df['price'].std()
# Out:
# 664.2305385854249

# %%
#Contagem
df['price'].count
# Out:
# <bound method Series.count of 0        130.98
# 1        170.79
# 2          7.31
# 3        191.52
# 4         13.98
#          ...
# 1888      27.19
# 1889     323.98
# 1890     224.94
# 1891     197.72
# 1892    1499.97
# Name: price, Length: 1893, dtype: float64>

# %%
#Moda
df['price'].mode
# Out:
# <bound method Series.mode of 0        130.98
# 1        170.79
# 2          7.31
# 3        191.52
# 4         13.98
#          ...
# 1888      27.19
# 1889     323.98
# 1890     224.94
# 1891     197.72
# 1892    1499.97
# Name: price, Length: 1893, dtype: float64>

# %%
#Máximo
df['price'].max()
# Out:
# 22638.48

# %%
#Mínimo
df['price'].min()
# Out:
# 0.44

# %%
#Índice do valor máximo
df['price'].idxmax()
# Out:
# 1429

# %%
#Índice do valor mínimo
df['price'].idxmin()
# Out:
# 1118

# %% [markdown]
# #Selecionando pelo Índice - ILOC

# %%
#Em uma mesma coluna
df.iloc[100]
# Out:
# Id_Product                             TEC-AC-10001552
# category                                    Technology
# sub_category                               Accessories
# product_name    Logitech K350 2.4Ghz Wireless Keyboard
# price                                            99.54
# Name: 100, dtype: object

# %%
#Em uma mesma linha
df.iloc[[0]]
# Out:
#         Id_Product   category sub_category                       product_name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     price
# 0  130.98

# %%
#Selecionado várias linhas
df.iloc[[100,101,102]]
# Out:
#           Id_Product         category sub_category  \
# 100  TEC-AC-10001552       Technology  Accessories
# 101  FUR-FU-10004006        Furniture  Furnishings
# 102  OFF-BI-10002794  Office Supplies      Binders
#
#                                           product_name  price
# 100             Logitech K350 2.4Ghz Wireless Keyboard  99.54
# 101  Deflect-o DuraMat Lighweight, Studded, Beveled...  85.30
# 102  Avery Trapezoid Ring Binder, 3" Capacity, Blac...  12.29

# %%
#Selecionado várias linhas entre índicas
df.iloc[100:105]
# Out:
#           Id_Product         category sub_category  \
# 100  TEC-AC-10001552       Technology  Accessories
# 101  FUR-FU-10004006        Furniture  Furnishings
# 102  OFF-BI-10002794  Office Supplies      Binders
# 103  TEC-AC-10003499       Technology  Accessories
# 104  TEC-PH-10002844       Technology       Phones
#
#                                           product_name  price
# 100             Logitech K350 2.4Ghz Wireless Keyboard  99.54
# 101  Deflect-o DuraMat Lighweight, Studded, Beveled...  85.30
# 102  Avery Trapezoid Ring Binder, 3" Capacity, Blac...  12.29
# 103  Memorex Mini Travel Drive 8 GB USB 2.0 Flash D...  18.53
# 104                Speck Products Candyshell Flip Case  27.99

# %%
df['category'].iloc[100]
# Out:
# 'Technology'

# %%
df[['sub_category','price']].iloc[100]
# Out:
# sub_category    Accessories
# price                 99.54
# Name: 100, dtype: object

# %% [markdown]
# #Operador de Seleção - LOC (Filtro)

# %%
df.loc[df['category']=='Technology']
# Out:
#            Id_Product    category sub_category  \
# 7     TEC-PH-10002275  Technology       Phones
# 11    TEC-PH-10002033  Technology       Phones
# 19    TEC-PH-10001949  Technology       Phones
# 25    TEC-AC-10003027  Technology  Accessories
# 34    TEC-PH-10004977  Technology       Phones
# ...               ...         ...          ...
# 1887  TEC-MA-10003493  Technology     Machines
# 1888  TEC-AC-10002380  Technology  Accessories
# 1889  TEC-PH-10002817  Technology       Phones
# 1890  TEC-MA-10003589  Technology     Machines
# 1892  TEC-PH-10002645  Technology       Phones
#
#                                           product_name    price
# 7                       Mitel 5320 IP Phone VoIP phone   302.38
# 11       Konftel 250 Conference phone - Charcoal black   284.82
# 19                             Cisco SPA 501G IP Phone   213.48
# 25    Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.57
# 34                                         GE 30524EE4   235.19
# ...                                                ...      ...
# 1887               Penpower WorldCard Pro Card Scanner    91.48
# 1888      Sony 8GB Class 10 Micro SDHC R40 Memory Card    27.19
# 1889                   RCA ViSYS 25425RE1 Corded phone   323.98
# 1890                      Cisco 8961 IP Phone Charcoal   224.94
# 1892                                             LG G2  1499.97
#
# [413 rows x 5 columns]

# %%
#Selecionando colunas específicas para filtrar
df[['Id_Product','category','price']].loc[df['category']=='Technology']
# Out:
#            Id_Product    category    price
# 1872  TEC-MA-10004552  Technology  1035.80
# 1876  TEC-MA-10002694  Technology   101.99
# 1877  TEC-MA-10004626  Technology   120.00
# 1878  TEC-PH-10004241  Technology  1439.97
# 1880  TEC-MA-10003337  Technology   179.99
# 1887  TEC-MA-10003493  Technology    91.48
# 1888  TEC-AC-10002380  Technology    27.19
# 1889  TEC-PH-10002817  Technology   323.98
# 1890  TEC-MA-10003589  Technology   224.94
# 1892  TEC-PH-10002645  Technology  1499.97

# %%
#Utilizando vários filtros
df[['Id_Product','category','sub_category','price']]\
.loc[(df['category']=='Technology') \
     & (df['sub_category']=='Phones')]
# Out:
#            Id_Product    category sub_category    price
# 7     TEC-PH-10002275  Technology       Phones   302.38
# 11    TEC-PH-10002033  Technology       Phones   284.82
# 19    TEC-PH-10001949  Technology       Phones   213.48
# 34    TEC-PH-10004977  Technology       Phones   235.19
# 39    TEC-PH-10000486  Technology       Phones   371.17
# ...               ...         ...          ...      ...
# 1836  TEC-PH-10002070  Technology       Phones    13.49
# 1839  TEC-PH-10004094  Technology       Phones   249.58
# 1878  TEC-PH-10004241  Technology       Phones  1439.97
# 1889  TEC-PH-10002817  Technology       Phones   323.98
# 1892  TEC-PH-10002645  Technology       Phones  1499.97
#
# [189 rows x 4 columns]

# %% [markdown]
# #Groupby - Agrupar Informações

# %%
#Agrupando preço médio por categoria
df.groupby('sub_category').mean()
# Out:
#                     price
# sub_category
# Accessories    100.127347
# Appliances     112.207576
# Art             22.947439
# Binders         43.114178
# Bookcases      246.455400
# Chairs         226.836932
# Copiers       1324.598462
# Envelopes       39.570000
# Fasteners        6.682558
# Furnishings     44.221702
# Labels          13.262143
# Machines      1381.303750
# Paper           27.560387
# Phones         190.443915
# Storage        112.531061
# Supplies       148.975263
# Tables         263.875088

# %%
df.groupby('sub_category').sum()
# Out:
#                  price
# sub_category
# Accessories   14718.72
# Appliances    11108.55
# Art            3763.38
# Binders        9183.32
# Bookcases     12322.77
# Chairs        19961.65
# Copiers       17219.78
# Envelopes      2136.78
# Fasteners       287.35
# Furnishings    8313.68
# Labels          928.35
# Machines      88403.44
# Paper          7827.15
# Phones        35993.90
# Storage       14854.10
# Supplies       5661.06
# Tables        15040.88

# %%
df.groupby(['category','sub_category']).median()
# Out:
#                                 price
# category        sub_category
# Furniture       Bookcases     158.675
#                 Chairs        167.275
#                 Furnishings    22.305
#                 Tables        209.670
# Office Supplies Appliances     33.620
#                 Art             8.010
#                 Binders         5.680
#                 Envelopes      15.605
#                 Fasteners       5.670
#                 Labels          6.605
#                 Paper          12.960
#                 Storage        51.575
#                 Supplies       12.340
# Technology      Accessories    47.980
#                 Copiers       799.980
#                 Machines      448.535
#                 Phones        116.980

# %% [markdown]
# #Ordenar dados

# %%
#Ordenando do maior para o menor em relação ao preço
df.sort_values('price',ascending=False).head()
# Out:
#            Id_Product    category sub_category  \
# 1429  TEC-MA-10002412  Technology     Machines
# 1405  TEC-CO-10004722  Technology      Copiers
# 577   TEC-MA-10004125  Technology     Machines
# 1673  TEC-MA-10001047  Technology     Machines
# 293   TEC-MA-10002927  Technology     Machines
#
#                                            product_name     price
# 1429  Cisco TelePresence System EX90 Videoconferenci...  22638.48
# 1405              Canon imageCLASS 2200 Advanced Copier   8399.98
# 577           Cubify CubeX 3D Printer Triple Head Print   7999.98
# 1673   3D Systems Cube Printer, 2nd Generation, Magenta   5199.96
# 293   Canon imageCLASS MF7460 Monochrome Digital Las...   3991.98

# %%
#Ordenando do menor para o maior em relação ao preço
df.sort_values('price',ascending=True).head()
# Out:
#            Id_Product         category sub_category  \
# 1118  OFF-AP-10002906  Office Supplies   Appliances
# 762   OFF-BI-10004022  Office Supplies      Binders
# 813   OFF-BI-10003727  Office Supplies      Binders
# 804   OFF-BI-10003529  Office Supplies      Binders
# 237   OFF-BI-10003460  Office Supplies      Binders
#
#                                            product_name  price
# 1118  Hoover Replacement Belt for Commercial Guardsm...   0.44
# 762            Acco Suede Grain Vinyl Round Ring Binder   0.56
# 813   Avery Durable Slant Ring Binders With Label Ho...   0.84
# 804                       Avery Round Ring Poly Binders   0.85
# 237                                   Acco 3-Hole Punch   0.88

# %% [markdown]
# #Exercício
# Fazer a análise exploratória do data set abaixo
# https://www.kaggle.com/datasets/iamsouravbanerjee/world-population-dataset/code
#
#
#
# *   População total de 2022
# *   Média da Taxa de Crescimento (Growth Rate)
# *   Buscar informações do Brasil (Brazil)
# *   Listar 5 países com maiores populações em 2022
# *   Fazer a diferença da população entre 2022 e 2020
# *   Listar 10 países com maior diferença de população entre 2022 e 2020

# %% [markdown]
# #Resposta

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

df = pd.read_csv('../input/world-population-dataset/world_population.csv')
df.head()
df.info()
df.describe()
df['2022 Population'].sum()
df['Growth Rate'].mean()
df.loc[df['Country']=='Brazil'].sum()
df[['Country','2022 Population']].sort_values('2022 Population', ascending=False).head()
df['dif'] = df['2022 Population'] - df['2020 Population']
df[['Country','dif']].groupby('Country').sum('dif').sort_values('dif',ascending=False).head(10)

# %% [markdown]
# # Join & Merge
